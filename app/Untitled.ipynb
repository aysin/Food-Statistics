# %%
import json
with open('../foodstats.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {u'meta': {u'code': 200,
#   u'limit': 100,
#   u'next_offset': 658330804,
#   u'offset': 0},
#  u'response': [{u'food__category_id': 128,
#    u'food_id': 293161,
#    u'id': 658330693},
#   {u'food__category_id': 83, u'food_id': 13814910, u'id': 658330694},
#   {u'food__category_id': 49, u'food_id': 6106923, u'id': 658330695},
#   {u'food__category_id': 34, u'food_id': 7394208, u'id': 658330696},
#   {u'food__category_id': 29, u'food_id': 12275443, u'id': 658330697},
#   {u'food__category_id': 8, u'food_id': 279459, u'id': 658330698},
#   {u'food__category_id': 69, u'food_id': 212658, u'id': 658330699},
#   {u'food__category_id': 8, u'food_id': 12274813, u'id': 658330704},
#   {u'food__category_id': 29, u'food_id': 224619, u'id': 658330705},
#   {u'food__category_id': 103, u'food_id': 2320413, u'id': 658330706},
#   {u'food__category_id': 31, u'food_id': 5703235, u'id': 658330707},
#   {u'food__category_id': 31, u'food_id': 466575, u'id': 658330708},
# ...

# %%
data.keys()
# Out:
# [u'meta', u'response']

# %%
data['meta']
# Out:
# {u'code': 200, u'limit': 100, u'next_offset': 658330804, u'offset': 0}

# %%
data['response']
# Out:
# [{u'food__category_id': 128, u'food_id': 293161, u'id': 658330693},
#  {u'food__category_id': 83, u'food_id': 13814910, u'id': 658330694},
#  {u'food__category_id': 49, u'food_id': 6106923, u'id': 658330695},
#  {u'food__category_id': 34, u'food_id': 7394208, u'id': 658330696},
#  {u'food__category_id': 29, u'food_id': 12275443, u'id': 658330697},
#  {u'food__category_id': 8, u'food_id': 279459, u'id': 658330698},
#  {u'food__category_id': 69, u'food_id': 212658, u'id': 658330699},
#  {u'food__category_id': 8, u'food_id': 12274813, u'id': 658330704},
#  {u'food__category_id': 29, u'food_id': 224619, u'id': 658330705},
#  {u'food__category_id': 103, u'food_id': 2320413, u'id': 658330706},
#  {u'food__category_id': 31, u'food_id': 5703235, u'id': 658330707},
#  {u'food__category_id': 31, u'food_id': 466575, u'id': 658330708},
#  {u'food__category_id': 46, u'food_id': 14359217, u'id': 658330709},
#  {u'food__category_id': 31, u'food_id': 47233, u'id': 658330710},
# ...

# %%
food_ids = {}

for item in data['response']:
    if food_ids.has_key(item['food_id']):
        food_ids[item['food_id']] +=1
    else:
        food_ids[item['food_id']] = 1

# %%
food_ids
# Out:
# {749: 1,
#  5306: 1,
#  8801: 1,
#  36155: 1,
#  47233: 1,
#  48722: 1,
#  67024: 1,
#  121243: 1,
#  150387: 2,
#  169810: 1,
#  212447: 1,
#  212658: 1,
#  222538: 1,
#  224619: 1,
#  230687: 1,
#  254225: 1,
#  254563: 1,
#  275877: 1,
#  279459: 1,
#  290120: 1,
#  293161: 1,
#  443572: 1,
#  452983: 1,
#  459850: 1,
#  466575: 1,
#  637576: 1,
#  649942: 1,
#  778683: 1,
#  889355: 1,
#  930805: 1,
#  1054800: 1,
#  1056324: 1,
#  1309444: 1,
#  1573799: 1,
#  1694057: 1,
#  1835483: 1,
#  1944759: 1,
#  2078352: 1,
#  2111978: 1,
#  2143667: 1,
#  2265059: 1,
#  2320413: 1,
#  2408846: 1,
#  2632374: 1,
#  2639697: 1,
#  2731667: 1,
#  2882275: 1,
#  2963597: 1,
#  3843598: 1,
#  3851591: 1,
#  4231829: 1,
#  4282123: 1,
#  5238041: 1,
#  5289987: 1,
#  5426777: 1,
#  5431283: 1,
#  5703235: 1,
#  6106923: 1,
#  6294781: 1,
#  7258687: 1,
#  7394208: 1,
#  8229854: 1,
#  8420932: 1,
#  10079672: 1,
#  10119528: 1,
#  11350741: 1,
#  11374835: 1,
#  12000902: 1,
#  12272900: 1,
# ...

# %%
food_ids
# Out:
# {749: 1,
#  5306: 1,
#  8801: 1,
#  36155: 1,
#  47233: 1,
#  48722: 1,
#  67024: 1,
#  121243: 1,
#  150387: 1,
#  169810: 1,
#  212447: 1,
#  212658: 1,
#  222538: 1,
#  224619: 1,
#  230687: 1,
#  254225: 1,
#  254563: 1,
#  275877: 1,
#  279459: 1,
#  290120: 1,
#  293161: 1,
#  443572: 1,
#  452983: 1,
#  459850: 1,
#  466575: 1,
#  637576: 1,
#  649942: 1,
#  778683: 1,
#  889355: 1,
#  930805: 1,
#  1054800: 1,
#  1056324: 1,
#  1309444: 1,
#  1573799: 1,
#  1694057: 1,
#  1835483: 1,
#  1944759: 1,
#  2078352: 1,
#  2111978: 1,
#  2143667: 1,
#  2265059: 1,
#  2320413: 1,
#  2408846: 1,
#  2632374: 1,
#  2639697: 1,
#  2731667: 1,
#  2882275: 1,
#  2963597: 1,
#  3843598: 1,
#  3851591: 1,
#  4231829: 1,
#  4282123: 1,
#  5238041: 1,
#  5289987: 1,
#  5426777: 1,
#  5431283: 1,
#  5703235: 1,
#  6106923: 1,
#  6294781: 1,
#  7258687: 1,
#  7394208: 1,
#  8229854: 1,
#  8420932: 1,
#  10079672: 1,
#  10119528: 1,
#  11350741: 1,
#  11374835: 1,
#  12000902: 1,
#  12272900: 1,
# ...
